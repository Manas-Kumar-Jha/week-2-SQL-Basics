# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
df = pd.read_csv("SampleSuperstore.csv", encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), str(15)
# memory usage: 3.3 MB

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Saritamanas@123"
)

cursor = conn.cursor()
cursor.execute("CREATE DATABASE IF NOT EXISTS superstore_db")

print("Database Created")
# Out:
# Database Created

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus("Saritamanas@123")

engine = create_engine(
    f"mysql+mysqlconnector://root:{password}@localhost/superstore_db"
)

connection = engine.connect()

print("Engine Connected Successfully")
# Out:
# Engine Connected Successfully

# %%
df.to_sql(
    "superstore",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data Uploaded Successfully")
# Out:
# Data Uploaded Successfully

# %%
query = """
SELECT COUNT(*) AS Total_Rows
FROM superstore;
"""

pd.read_sql(query, engine)
# Out:
#    Total_Rows
# 0        9994

# %%
query = """
SELECT *
FROM superstore
LIMIT 10;
"""

pd.read_sql(query, engine)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7       90032    West  TEC-PH-10002275       Technology       Phones
# 8       90032    West  OFF-BI-10003910  Office Supplies      Binders
# 9       90032    West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700
#
# [10 rows x 21 columns]

# %%
query = """
SELECT *
FROM superstore
WHERE Region='West';
"""

pd.read_sql(query, engine)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 1          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 2          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 3          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 4          9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 3198    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 3199    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 3200    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 3201    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 3202    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# 0       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# 1       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 2       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 3       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 4       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# ...          ...              ...        ...            ...          ...  ...
# 3198    ML-17410     Maris LaWare   Consumer  United States  Los Angeles  ...
# 3199    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 3200    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 3201    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 3202    CC-12220     Chris Cortes   Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 0          90036    West  OFF-LA-10000240  Office Supplies       Labels
# 1          90032    West  FUR-FU-10001487        Furniture  Furnishings
# 2          90032    West  OFF-AR-10002833  Office Supplies          Art
# 3          90032    West  TEC-PH-10002275       Technology       Phones
# 4          90032    West  OFF-BI-10003910  Office Supplies      Binders
# ...          ...     ...              ...              ...          ...
# 3198       90008    West  TEC-AC-10003399       Technology  Accessories
# 3199       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 3200       92627    West  TEC-PH-10003645       Technology       Phones
# 3201       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 3202       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 0     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 1     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 2                                            Newell 322    7.280         4
# 3                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 4     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 3198  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 3199  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 3200                              Aastra 57i VoIP phone  258.576         2
# 3201  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 3202  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       Discount   Profit
# 0          0.0   6.8714
# 1          0.0  14.1694
# 2          0.0   1.9656
# 3          0.2  90.7152
# 4          0.2   5.7825
# ...        ...      ...
# 3198       0.0  15.2208
# 3199       0.0  15.6332
# 3200       0.2  19.3932
# 3201       0.0  13.3200
# 3202       0.0  72.9480
#
# [3203 rows x 21 columns]

# %%
query = """
SELECT *
FROM superstore
WHERE Sales > 500;
"""

pd.read_sql(query, engine)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 2          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 3         11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 4         12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 1157    9932  CA-2015-104948 2015-11-13 2015-11-17  Standard Class
# 1158    9943  CA-2014-143371 2014-12-28 2015-01-03  Standard Class
# 1159    9948  CA-2017-121559 2017-06-01 2017-06-03    Second Class
# 1160    9949  CA-2017-121559 2017-06-01 2017-06-03    Second Class
# 1161    9969  CA-2017-153871 2017-12-11 2017-12-17  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# 1       SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2       BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 3       BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# 4       BH-11710  Brosina Hoffman   Consumer  United States      Los Angeles
# ...          ...              ...        ...            ...              ...
# 1157    KH-16510    Keith Herrera   Consumer  United States   San Bernardino
# 1158    MD-17350    Maribeth Dona   Consumer  United States          Anaheim
# 1159    HW-14935  Helen Wasserman  Corporate  United States     Indianapolis
# 1160    HW-14935  Helen Wasserman  Corporate  United States     Indianapolis
# 1161    RB-19435  Richard Bierner   Consumer  United States       Plainfield
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 0     ...       42420    South  FUR-CH-10000454        Furniture       Chairs
# 1     ...       33311    South  FUR-TA-10000577        Furniture       Tables
# 2     ...       90032     West  TEC-PH-10002275       Technology       Phones
# 3     ...       90032     West  FUR-TA-10001539        Furniture       Tables
# 4     ...       90032     West  TEC-PH-10002033       Technology       Phones
# ...   ...         ...      ...              ...              ...          ...
# 1157  ...       92404     West  FUR-BO-10004357        Furniture    Bookcases
# 1158  ...       92804     West  OFF-ST-10001128  Office Supplies      Storage
# 1159  ...       46203  Central  FUR-CH-10003746        Furniture       Chairs
# 1160  ...       46203  Central  OFF-AP-10002945  Office Supplies   Appliances
# 1161  ...        7060     East  OFF-BI-10004600  Office Supplies      Binders
#
#                                            Product Name      Sales  Quantity  \
# 0     Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 1         Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 2                        Mitel 5320 IP Phone VoIP phone   907.1520         6
# 3              Chromcraft Rectangular Conference Tables  1706.1840         9
# 4         Konftel 250 Conference phone - Charcoal black   911.4240         4
# ...                                                 ...        ...       ...
# 1157     O'Sullivan Living Dimensions 3-Shelf Bookcases   683.3320         4
# 1158        Carina Mini System Audio Rack, Model AR050B   998.8200         9
# 1159  Hon 4070 Series Pagoda Round Back Stacking Chairs  1925.8800         6
# 1160  Honeywell Enviracaire Portable HEPA Air Cleane...  2405.2000         8
# 1161          Ibico Ibimaster 300 Manual Binding System   735.9800         2
#
#       Discount    Profit
# 0         0.00  219.5820
# 1         0.45 -383.0310
# 2         0.20   90.7152
# 3         0.20   85.3092
# 4         0.20   68.3568
# ...        ...       ...
# 1157      0.15  -40.1960
# 1158      0.00   29.9646
# 1159      0.00  539.2464
# 1160      0.00  793.7160
# 1161      0.00  331.1910
#
# [1162 rows x 21 columns]

# %%
query = """
SELECT *
FROM superstore
WHERE Category='Furniture';
"""

pd.read_sql(query, engine)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 3          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 4         11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 2116    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
# 2117    9965  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 2118    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 2119    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 2120    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# 1       CG-12520       Claire Gute     Consumer  United States
# 2       SO-20335    Sean O'Donnell     Consumer  United States
# 3       BH-11710   Brosina Hoffman     Consumer  United States
# 4       BH-11710   Brosina Hoffman     Consumer  United States
# ...          ...               ...          ...            ...
# 2116    CM-12655  Corinna Mitchell  Home Office  United States
# 2117    HE-14800      Harold Engle    Corporate  United States
# 2118    SW-20455       Shaun Weien     Consumer  United States
# 2119    TB-21400  Tom Boeckenhauer     Consumer  United States
# 2120    DB-13060       Dave Brooks     Consumer  United States
#
#                  City  ... Postal Code   Region       Product ID   Category  \
# 0           Henderson  ...       42420    South  FUR-BO-10001798  Furniture
# 1           Henderson  ...       42420    South  FUR-CH-10000454  Furniture
# 2     Fort Lauderdale  ...       33311    South  FUR-TA-10000577  Furniture
# 3         Los Angeles  ...       90032     West  FUR-FU-10001487  Furniture
# 4         Los Angeles  ...       90032     West  FUR-TA-10001539  Furniture
# ...               ...  ...         ...      ...              ...        ...
# 2116          Houston  ...       77041  Central  FUR-BO-10004218  Furniture
# 2117           Newark  ...       19711     East  FUR-FU-10002671  Furniture
# 2118        Lafayette  ...       70506    South  FUR-TA-10001039  Furniture
# 2119            Miami  ...       33180    South  FUR-FU-10001889  Furniture
# 2120       Costa Mesa  ...       92627     West  FUR-FU-10000747  Furniture
#
#      Sub-Category                                       Product Name  \
# 0       Bookcases                  Bush Somerset Collection Bookcase
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2          Tables      Bretford CR4500 Series Slim Rectangular Table
# 3     Furnishings  Eldon Expressions Wood and Plastic Desk Access...
# 4          Tables           Chromcraft Rectangular Conference Tables
# ...           ...                                                ...
# 2116    Bookcases  Bush Heritage Pine Collection 5-Shelf Bookcase...
# 2117  Furnishings  Electrix 20W Halogen Replacement Bulb for Zoom...
# 2118       Tables                         KI Adjustable-Height Table
# 2119  Furnishings                             Ultra Door Pull Handle
# 2120  Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...
#
#           Sales  Quantity  Discount    Profit
# 0      261.9600         2      0.00   41.9136
# 1      731.9400         3      0.00  219.5820
# 2      957.5775         5      0.45 -383.0310
# 3       48.8600         7      0.00   14.1694
# 4     1706.1840         9      0.20   85.3092
# ...         ...       ...       ...       ...
# 2116   383.4656         4      0.32  -67.6704
# 2117    13.4000         1      0.00    6.4320
# 2118    85.9800         1      0.00   22.3548
# 2119    25.2480         3      0.20    4.1028
# 2120    91.9600         2      0.00   15.6332
#
# [2121 rows x 21 columns]

# %%
query = """
SELECT *
FROM superstore
WHERE Region='East'
AND Sales > 1000;
"""

pd.read_sql(query, engine)
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        28  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 1        55  CA-2016-105816 2016-12-11 2016-12-17  Standard Class    JM-15265
# 2       216  CA-2015-146262 2015-01-02 2015-01-09  Standard Class    VW-21775
# 3       300  CA-2016-142545 2016-10-28 2016-11-03  Standard Class    JD-15895
# 4       319  CA-2014-164973 2014-11-04 2014-11-09  Standard Class    NM-18445
# ..      ...             ...        ...        ...             ...         ...
# 138    9674  CA-2016-114867 2016-12-23 2016-12-28  Standard Class    FM-14290
# 139    9713  CA-2014-114251 2014-11-05 2014-11-10  Standard Class    MD-17350
# 140    9742  CA-2015-117086 2015-11-08 2015-11-12  Standard Class    QJ-19255
# 141    9867  US-2015-116981 2015-03-26 2015-03-28    Second Class    SM-20950
# 142    9926  CA-2015-159534 2015-03-20 2015-03-23     First Class    DH-13075
#
#         Customer Name      Segment        Country           City  ...  \
# 0     Tracy Blumstein     Consumer  United States   Philadelphia  ...
# 1      Janet Molinari    Corporate  United States  New York City  ...
# 2     Victoria Wilson    Corporate  United States         Medina  ...
# 3    Jonathan Doherty    Corporate  United States     Belleville  ...
# 4        Nathan Mautz  Home Office  United States  New York City  ...
# ..                ...          ...            ...            ...  ...
# 138      Frank Merwin  Home Office  United States   Philadelphia  ...
# 139     Maribeth Dona     Consumer  United States   Philadelphia  ...
# 140      Quincy Jones    Corporate  United States     Burlington  ...
# 141    Suzanne McNair    Corporate  United States  New York City  ...
# 142     Dave Hallsten    Corporate  United States  New York City  ...
#
#     Postal Code  Region       Product ID         Category Sub-Category  \
# 0         19140    East  FUR-BO-10004834        Furniture    Bookcases
# 1         10024    East  TEC-PH-10002447       Technology       Phones
# 2         44256    East  TEC-MA-10000864       Technology     Machines
# 3          7109    East  OFF-ST-10002756  Office Supplies      Storage
# 4         10024    East  TEC-MA-10002927       Technology     Machines
# ..          ...     ...              ...              ...          ...
# 138       19143    East  TEC-PH-10002645       Technology       Phones
# 139       19143    East  OFF-ST-10003716  Office Supplies      Storage
# 140        5408    East  FUR-BO-10004834        Furniture    Bookcases
# 141       10009    East  OFF-ST-10002615  Office Supplies      Storage
# 142       10035    East  OFF-BI-10003656  Office Supplies      Binders
#
#                                           Product Name     Sales  Quantity  \
# 0    Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430         7
# 1                     AT&T CL83451 4-Handset Telephone  1029.950         5
# 2                   Cisco 9971 IP Video Phone Charcoal  1188.000         9
# 3    Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...  1082.480         8
# 4    Canon imageCLASS MF7460 Monochrome Digital Las...  3991.980         2
# ..                                                 ...       ...       ...
# 138                                              LG G2  1499.970         5
# 139                        Tennsco Double-Tier Lockers  1080.096         6
# 140  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.900         5
# 141              Dual Level, Single-Width Filing Carts  1085.420         7
# 142        Fellowes PB200 Plastic Comb Binding Machine  1087.936         8
#
#      Discount     Profit
# 0         0.5 -1665.0522
# 1         0.0   298.6855
# 2         0.7  -950.4000
# 3         0.0    10.8248
# 4         0.0  1995.9900
# ..        ...        ...
# 138       0.4  -374.9925
# 139       0.2   -94.5084
# 140       0.0  1013.1270
# 141       0.0   282.2092
# 142       0.2   353.5792
#
# [143 rows x 21 columns]

# %%
query = """
SELECT Region,
       ROUND(SUM(Sales),2) AS Total_Sales
FROM superstore
GROUP BY Region;
"""

pd.read_sql(query, engine)
# Out:
#     Region  Total_Sales
# 0    South    391721.91
# 1     West    725457.82
# 2  Central    501239.89
# 3     East    678781.24

# %%
query = """
SELECT Category,
       SUM(Quantity) AS Total_Quantity
FROM superstore
GROUP BY Category;
"""

pd.read_sql(query, engine)
# Out:
#           Category  Total_Quantity
# 0        Furniture          8028.0
# 1  Office Supplies         22906.0
# 2       Technology          6939.0

# %%
query = """
SELECT Category,
       ROUND(AVG(Profit),2) AS Avg_Profit
FROM superstore
GROUP BY Category;
"""

pd.read_sql(query, engine)
# Out:
#           Category  Avg_Profit
# 0        Furniture        8.70
# 1  Office Supplies       20.33
# 2       Technology       78.75

# %%
query = """
SELECT `Product Name`,
       ROUND(SUM(Sales),2) AS Revenue
FROM superstore
GROUP BY `Product Name`
ORDER BY Revenue DESC
LIMIT 10;
"""

pd.read_sql(query, engine)
# Out:
#                                         Product Name   Revenue
# 0              Canon imageCLASS 2200 Advanced Copier  61599.82
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.38
# 2  Cisco TelePresence System EX90 Videoconferenci...  22638.48
# 3       HON 5400 Series Task Chairs for Big and Tall  21870.58
# 4         GBC DocuBind TL300 Electric Binding System  19823.48
# 5   GBC Ibimaster 500 Manual ProClick Binding System  19024.50
# 6               Hewlett Packard LaserJet 3310 Copier  18839.69
# 7  HP Designjet T520 Inkjet Large Format Printer ...  18374.90
# 8          GBC DocuBind P400 Electric Binding System  17965.07
# 9        High Speed Automatic Electric Letter Opener  17030.31

# %%
query = """
SELECT `Customer Name`,
       ROUND(SUM(Sales),2) AS Revenue
FROM superstore
GROUP BY `Customer Name`
ORDER BY Revenue DESC
LIMIT 5;
"""

pd.read_sql(query, engine)
# Out:
#    Customer Name   Revenue
# 0    Sean Miller  25043.05
# 1   Tamara Chand  19052.22
# 2   Raymond Buch  15117.34
# 3   Tom Ashbrook  14595.62
# 4  Adrian Barton  14473.57

# %%
query = """
SELECT
DATE_FORMAT(`Order Date`,'%Y-%m') AS Month,
ROUND(SUM(Sales),2) AS Revenue
FROM superstore
GROUP BY Month
ORDER BY Month;
"""

pd.read_sql(query, engine)
# Out:
#       Month    Revenue
# 0   2014-01   14236.89
# 1   2014-02    4519.89
# 2   2014-03   55691.01
# 3   2014-04   28295.34
# 4   2014-05   23648.29
# 5   2014-06   34595.13
# 6   2014-07   33946.39
# 7   2014-08   27909.47
# 8   2014-09   81777.35
# 9   2014-10   31453.39
# 10  2014-11   78628.72
# 11  2014-12   69545.62
# 12  2015-01   18174.08
# 13  2015-02   11951.41
# 14  2015-03   38726.25
# 15  2015-04   34195.21
# 16  2015-05   30131.69
# 17  2015-06   24797.29
# 18  2015-07   28765.32
# 19  2015-08   36898.33
# 20  2015-09   64595.92
# 21  2015-10   31404.92
# 22  2015-11   75972.56
# 23  2015-12   74919.52
# 24  2016-01   18542.49
# 25  2016-02   22978.82
# 26  2016-03   51715.88
# 27  2016-04   38750.04
# 28  2016-05   56987.73
# 29  2016-06   40344.53
# 30  2016-07   39261.96
# 31  2016-08   31115.37
# 32  2016-09   73410.02
# 33  2016-10   59687.75
# 34  2016-11   79411.97
# 35  2016-12   96999.04
# 36  2017-01   43971.37
# 37  2017-02   20301.13
# 38  2017-03   58872.35
# 39  2017-04   36521.54
# 40  2017-05   44261.11
# 41  2017-06   52981.73
# 42  2017-07   45264.42
# 43  2017-08   63120.89
# 44  2017-09   87866.65
# 45  2017-10   77776.92
# 46  2017-11  118447.83
# 47  2017-12   83829.32

# %%
query = """
SELECT `Customer Name`,
       ROUND(SUM(Sales),2) AS Revenue
FROM superstore
GROUP BY `Customer Name`
ORDER BY Revenue DESC
LIMIT 10;
"""

pd.read_sql(query, engine)
# Out:
#         Customer Name   Revenue
# 0         Sean Miller  25043.05
# 1        Tamara Chand  19052.22
# 2        Raymond Buch  15117.34
# 3        Tom Ashbrook  14595.62
# 4       Adrian Barton  14473.57
# 5        Ken Lonsdale  14175.23
# 6        Sanjit Chand  14142.33
# 7        Hunter Lopez  12873.30
# 8        Sanjit Engle  12209.44
# 9  Christopher Conant  12129.07

# %%
query = """
SELECT `Product Name`,
       ROUND(SUM(Profit),2) AS Profit
FROM superstore
GROUP BY `Product Name`
ORDER BY Profit DESC
LIMIT 10;
"""

pd.read_sql(query, engine)
# Out:
#                                         Product Name    Profit
# 0              Canon imageCLASS 2200 Advanced Copier  25199.93
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...   7753.04
# 2               Hewlett Packard LaserJet 3310 Copier   6983.88
# 3                 Canon PC1060 Personal Laser Copier   4570.93
# 4  HP Designjet T520 Inkjet Large Format Printer ...   4094.98
# 5                  Ativa V4110MDD Micro-Cut Shredder   3772.95
# 6   3D Systems Cube Printer, 2nd Generation, Magenta   3717.97
# 7  Plantronics Savi W720 Multi-Device Wireless He...   3696.28
# 8               Ibico EPK-21 Electric Binding System   3345.28
# 9                  Zebra ZM400 Thermal Label Printer   3343.54

# %%
query = """
SELECT `Product Name`,
       ROUND(SUM(Profit),2) AS Profit
FROM superstore
GROUP BY `Product Name`
ORDER BY Profit ASC
LIMIT 10;
"""

pd.read_sql(query, engine)
# Out:
#                                         Product Name   Profit
# 0          Cubify CubeX 3D Printer Double Head Print -8879.97
# 1          Lexmark MX611dhe Monochrome Laser Printer -4589.97
# 2          Cubify CubeX 3D Printer Triple Head Print -3839.99
# 3  Chromcraft Bull-Nose Wood Oval Conference Tabl... -2876.12
# 4  Bush Advantage Collection Racetrack Conference... -1934.40
# 5          GBC DocuBind P400 Electric Binding System -1878.17
# 6  Cisco TelePresence System EX90 Videoconferenci... -1811.08
# 7  Martin Yale Chadless Opener Electric Letter Op... -1299.18
# 8                       Balt Solid Wood Round Tables -1201.06
# 9  BoxOffice By Design Rectangular and Half-Moon ... -1148.44

# %%
query = """
SELECT `Order ID`,
COUNT(*) AS Duplicate_Count
FROM superstore
GROUP BY `Order ID`
HAVING COUNT(*) > 1;
"""

pd.read_sql(query, engine)
# Out:
#             Order ID  Duplicate_Count
# 0     CA-2016-152156                2
# 1     US-2015-108966                2
# 2     CA-2014-115812                7
# 3     US-2015-118983                2
# 4     CA-2014-143336                3
# ...              ...              ...
# 2466  US-2016-103674                7
# 2467  US-2016-157728                2
# 2468  CA-2015-100251                2
# 2469  CA-2017-163629                2
# 2470  CA-2017-121258                3
#
# [2471 rows x 2 columns]

# %%
query = """
SELECT COUNT(*) AS Total_Rows
FROM superstore;
"""

pd.read_sql(query, engine)
# Out:
#    Total_Rows
# 0        9994

# %%
query = """
SELECT *
FROM superstore
WHERE Profit < 0;
"""

pd.read_sql(query, engine)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 1         15  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 2         16  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 3         24  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 4         28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# ...      ...             ...        ...        ...             ...
# 1866    9921  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 1867    9922  CA-2014-111360 2014-11-24 2014-11-30  Standard Class
# 1868    9932  CA-2015-104948 2015-11-13 2015-11-17  Standard Class
# 1869    9938  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 1870    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       SO-20335    Sean O'Donnell     Consumer  United States
# 1       HP-14815     Harold Pawlan  Home Office  United States
# 2       HP-14815     Harold Pawlan  Home Office  United States
# 3       SF-20065   Sandra Flanagan     Consumer  United States
# 4       TB-21520   Tracy Blumstein     Consumer  United States
# ...          ...               ...          ...            ...
# 1866    MY-18295   Muhammed Yedwab    Corporate  United States
# 1867    AT-10435       Alyssa Tate  Home Office  United States
# 1868    KH-16510     Keith Herrera     Consumer  United States
# 1869    CP-12340    Christine Phan    Corporate  United States
# 1870    CM-12655  Corinna Mitchell  Home Office  United States
#
#                  City  ... Postal Code   Region       Product ID  \
# 0     Fort Lauderdale  ...       33311    South  FUR-TA-10000577
# 1          Fort Worth  ...       76106  Central  OFF-AP-10002311
# 2          Fort Worth  ...       76106  Central  OFF-BI-10000756
# 3        Philadelphia  ...       19140     East  FUR-CH-10002774
# 4        Philadelphia  ...       19140     East  FUR-BO-10004834
# ...               ...  ...         ...      ...              ...
# 1866            Bryan  ...       77803  Central  OFF-BI-10004233
# 1867            Akron  ...       44312     East  OFF-BI-10003350
# 1868   San Bernardino  ...       92404     West  FUR-BO-10004357
# 1869      Los Angeles  ...       90049     West  FUR-TA-10001676
# 1870          Houston  ...       77041  Central  FUR-BO-10004218
#
#              Category Sub-Category  \
# 0           Furniture       Tables
# 1     Office Supplies   Appliances
# 2     Office Supplies      Binders
# 3           Furniture       Chairs
# 4           Furniture    Bookcases
# ...               ...          ...
# 1866  Office Supplies      Binders
# 1867  Office Supplies      Binders
# 1868        Furniture    Bookcases
# 1869        Furniture       Tables
# 1870        Furniture    Bookcases
#
#                                            Product Name      Sales  Quantity  \
# 0         Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 1     Holmes Replacement Filter for HEPA Air Cleaner...    68.8100         5
# 2      Storex DuraTech Recycled Plastic Frosted Binders     2.5440         3
# 3                    Global Deluxe Stacking Chair, Gray    71.3720         2
# 4     Riverside Palais Royal Lawyers Bookcase, Royal...  3083.4300         7
# ...                                                 ...        ...       ...
# 1866  GBC Pre-Punched Binding Paper, Plastic, White,...    22.3860         7
# 1867                    Acco Expandable Hanging Binders     5.7420         3
# 1868     O'Sullivan Living Dimensions 3-Shelf Bookcases   683.3320         4
# 1869       Hon 61000 Series Interactive Training Tables    71.0880         2
# 1870  Bush Heritage Pine Collection 5-Shelf Bookcase...   383.4656         4
#
#       Discount     Profit
# 0         0.45  -383.0310
# 1         0.80  -123.8580
# 2         0.80    -3.8160
# 3         0.30    -1.0196
# 4         0.50 -1665.0522
# ...        ...        ...
# 1866      0.80   -35.8176
# 1867      0.70    -4.5936
# 1868      0.15   -40.1960
# 1869      0.20    -1.7772
# 1870      0.32   -67.6704
#
# [1871 rows x 21 columns]

# %%
query = """
SELECT MAX(Discount) AS Highest_Discount
FROM superstore;
"""

pd.read_sql(query, engine)
# Out:
#    Highest_Discount
# 0               0.8
